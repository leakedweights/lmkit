# %%
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# ...

# %%
mapped_params = map_keys(frozen_params)
print(f"Param keys: {mapped_params.keys()}")
print(f"Layer structure: {mapped_params['layers'][0].keys()}")
print(f"FFN structure: {mapped_params['layers'][0]['ffn'].keys()}")
print(f"Attn structure: {mapped_params['layers'][0]['attn'].keys()}")
# Out:
# Param keys: dict_keys(['embed_table', 'layers', 'out_norm'])
# Layer type: <class 'list'>
# Layer structure: dict_keys(['input_norm', 'ffn', 'post_attn_norm', 'post_ffn_norm', 'pre_ffn_norm', 'attn'])
# FFN structure: dict_keys(['W_down', 'W_gate', 'W_up'])
# Attn structure: dict_keys(['W_k', 'W_o', 'W_q', 'W_v'])

# %%
# Out:
# dict_keys(['embed_tokens', 'layers', 'norm'])

# %%
# Out:
# {0: {'input_layernorm': {'weight': Array([0.11663979, 0.13540989, 0.1913601 , ..., 0.636594  , 0.04109564,
#           0.24312384], dtype=float32)},
#   'mlp': {'down_proj': {'weight': Array([[-0.00075572,  0.0144901 ,  0.00175701, ..., -0.00056519,
#             -0.00920368, -0.00756989],
#            [ 0.00763638,  0.00635035,  0.00882725, ..., -0.00285222,
#              0.00307937,  0.00373391],
#            [ 0.01392252,  0.01341564, -0.00290946, ...,  0.00355499,
#             -0.00625261,  0.00239213],
#            ...,
#            [-0.00844482, -0.02389673,  0.00039425, ...,  0.02402695,
#             -0.00698289,  0.00221576],
#            [-0.00173752,  0.00043545, -0.00556295, ...,  0.01054019,
#             -0.00709657, -0.00331029],
#            [-0.01259559, -0.00851944, -0.01073654, ..., -0.00782933,
#              0.00528788,  0.01020982]], dtype=float32)},
#    'gate_proj': {'weight': Array([[ 2.6609513e-03, -1.7400380e-02, -3.4443811e-03, ...,
# ...
